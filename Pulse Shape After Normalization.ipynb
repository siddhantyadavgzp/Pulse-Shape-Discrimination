# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import numpy as np
from scipy.signal import savgol_filter

df= pd.read_csv('OneDrive/Documents/Karm/DNeutron.txt',header=None,sep=' ')
dk= pd.read_csv('OneDrive/Documents/Karm/DGamma.txt',header=None,sep=' ')
df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
dk.drop(dk.columns[len(df.columns)-1], axis=1, inplace=True)
mat=df.values
dat=dk.values

x=np.arange(191)
mi=min
plt.plot(x, mat[3], label='Neutron Pulse')
plt.plot(x, dat[0],label='Gamma Pulse')
plt.xlabel("Time")
plt.ylabel("Voltage")
plt.legend()
plt.show()
